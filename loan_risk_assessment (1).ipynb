# %%
from datetime import datetime
import joblib
import pandas as pd
from matplotlib import pyplot as plt
# import mlflow
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_selector, ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from xgboost import XGBClassifier

# %% [markdown]
# # Exploratory Data Analysis

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from datarobot.models.dataset import Dataset

# Retrieve a dataset from AI Catalog using its ID
dataset_id = "66059ec49b2d6a16e53456f9"
dataset = Dataset.get(dataset_id)

# Load the dataset into an in-memory pandas dataframe
df = dataset.get_as_dataframe()

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt        term  int_rate  installment grade sub_grade  \
# 0       1000         1000   36 months    0.1189        33.17     B        B4
# 1       3500         3500   36 months    0.1189       116.08     B        B4
# 2       3000         3000   36 months    0.1189        99.50     B        B4
# 3      12000        12000   36 months    0.1189       397.97     B        B4
# 4       4000         4000   36 months    0.1189       132.66     B        B4
#
#                                      emp_title emp_length home_ownership  \
# 0  fairbanks northstar borough school district  10+ years       MORTGAGE
# 1                         Orphic Workshop, LLC    2 years           RENT
# 2                                Jon Felts LLC    2 years           RENT
# 3                        Albany Medical Center    3 years           RENT
# 4                                      NYC DOE    2 years           RENT
#
#    annual_inc verification_status  pymnt_plan  \
# 0     87000.0        not verified       False
# 1     30000.0        not verified       False
# 2     30000.0        not verified       False
# 3     40000.0        not verified       False
# 4     54000.0        not verified       False
#
#                                                  url  \
# 0  https://www.lendingclub.com/browse/loanDetail....
# 1  https://www.lendingclub.com/browse/loanDetail....
# 2  https://www.lendingclub.com/browse/loanDetail....
# 3  https://www.lendingclub.com/browse/loanDetail....
# 4  https://www.lendingclub.com/browse/loanDetail....
#
#                                                 desc             purpose  \
# 0  I recently combined a planned work trip with a...               other
# 1  I'm working on paying of my cards, one by one....         credit_card
# 2  I am a certified golf teaching professional wi...      small_business
# 3                     Using to pay down credit cards  debt_consolidation
# 4  Seeking an unsecured personal loan.  Will be p...              moving
#
#                            title zip_code addr_state    dti  delinq_2yrs  \
# 0   Parent Attend Navy Induction    997xx         AK   5.57          1.0
# 1  Refinancing credit card debt     871xx         NM  11.68          0.0
# 2                   Golf Academy    957xx         CA  18.28          0.0
# 3                       Personal    121xx         NY  14.88          0.0
# 4        Unsecured Personal Loan    112xx         NY  12.91          1.0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0       1986-03-01             0.0                    13.0
# 1       1990-05-01             0.0                    71.0
# 2       1989-12-01             0.0                    40.0
# 3       1992-03-01             0.0                     NaN
# 4       1997-10-01             1.0                     8.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                     NaN       5.0      0.0       5742        55.2
# 1                     NaN       5.0      0.0       4621        45.8
# 2                     NaN       9.0      0.0      14577        34.7
# 3                     NaN       3.0      0.0      15280        56.2
# 4                     NaN       8.0      0.0      24671        66.0
#
#    total_acc  initial_list_status  policy_code  loan_status Partition
# 0       18.0                False            1            0         T
# 1       20.0                False            1            0         T
# 2       13.0                False            1            0         T
# 3       14.0                False            1            0         T
# 4       35.0                False            1            0         T

# %% [markdown]
# # Feature Transformation

# %%
numeric_transform = SimpleImputer(strategy='constant', fill_value=0)
categoric_tranform = Pipeline(
    steps=[
        ('null_imputation', SimpleImputer(strategy='constant', fill_value='UNKNOWN')),
        ('ordinal_encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
    ]
)

# %%
# Col transfomer automatically handles right cols via datatypes
col_transformer = ColumnTransformer(
    transformers=[
        ('numeric', numeric_transform, make_column_selector(dtype_include=[float,int])),
        ('categoric', categoric_tranform, make_column_selector(dtype_include=object))
    ]
)

# %% [markdown]
# # Partitioning

# %%
training_data = df[df['Partition'] == "T"].drop(labels=['Partition'], axis=1)

# %%
training_data.shape
# Out:
# (6400, 33)

# %%
validation_data = df[df['Partition'] == "V"].drop(labels=['Partition'], axis=1)

# %%
validation_data.shape
# Out:
# (1600, 33)

# %%
X_train = training_data.drop(labels='loan_status', axis=1)
y_train = training_data['loan_status']
X_val = validation_data.drop(labels='loan_status', axis=1)
y_val = validation_data['loan_status']

# %% [markdown]
# # Model Training & Evalution

# %%
xgb_model = XGBClassifier(
    learning_rate=.1,
    n_estimators=100,
    objective="binary:logistic",
    eval_metric=["logloss"],
    early_stopping_rounds=10,
    verbose=True
)

# %%
# Creates the model pipeline object:
model = Pipeline(
    steps=[
        ('col_transformer', col_transformer),
        ('model', xgb_model)
    ]
)

# %%
model[:-1].fit(X_train)
# Out:
# Pipeline(steps=[('col_transformer',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f6135775d60>),
#                                                  ('categoric',
#                                                   Pipeline(steps=[('null_imputation',
#                                                                    SimpleImputer(fill_value='UNKNOWN',
#                                                                                  strategy='constant')),
#                                                                   ('ordinal_encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f60ec7d7160>)]))])

# %%
X_val = model[:-1].transform(X_val)

# %%
model.fit(
    X_train, 
    y_train, 
    model__eval_set=[(X_val, y_val)]
)
# Out:
# [21:14:03] WARNING: ../src/learner.cc:627:
# Parameters: { "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-logloss:0.64033
# [1]	validation_0-logloss:0.59637
# [2]	validation_0-logloss:0.56046
# [3]	validation_0-logloss:0.53176
# [4]	validation_0-logloss:0.50948
# [5]	validation_0-logloss:0.48927
# [6]	validation_0-logloss:0.47196
# [7]	validation_0-logloss:0.46006
# [8]	validation_0-logloss:0.44738
# [9]	validation_0-logloss:0.43571
# [10]	validation_0-logloss:0.42719
# [11]	validation_0-logloss:0.41932
# [12]	validation_0-logloss:0.41306
# [13]	validation_0-logloss:0.40639
# [14]	validation_0-logloss:0.40120
# [15]	validation_0-logloss:0.39671
# [16]	validation_0-logloss:0.39481
# [17]	validation_0-logloss:0.39148
# [18]	validation_0-logloss:0.39053
# [19]	validation_0-logloss:0.38828
# [20]	validation_0-logloss:0.38607
# [21]	validation_0-logloss:0.38380
# [22]	validation_0-logloss:0.38263
# [23]	validation_0-logloss:0.38148
# [24]	validation_0-logloss:0.38063
# [25]	validation_0-logloss:0.37977
# [26]	validation_0-logloss:0.38035
# [27]	validation_0-logloss:0.37977
# [28]	validation_0-logloss:0.37950
# [29]	validation_0-logloss:0.37992
# [30]	validation_0-logloss:0.37903
# [31]	validation_0-logloss:0.37942
# [32]	validation_0-logloss:0.37882
# [33]	validation_0-logloss:0.37878
# [34]	validation_0-logloss:0.37818
# [35]	validation_0-logloss:0.37770
# [36]	validation_0-logloss:0.37795
# [37]	validation_0-logloss:0.37746
# [38]	validation_0-logloss:0.37703
# [39]	validation_0-logloss:0.37730
# [40]	validation_0-logloss:0.37717
# [41]	validation_0-logloss:0.37756
# [42]	validation_0-logloss:0.37746
# [43]	validation_0-logloss:0.37835
# [44]	validation_0-logloss:0.37854
# [45]	validation_0-logloss:0.37854
# [46]	validation_0-logloss:0.37849
# [47]	validation_0-logloss:0.37877
# [48]	validation_0-logloss:0.37876
# Pipeline(steps=[('col_transformer',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f6135775d60>),
#                                                  ('categoric',
#                                                   Pipeline(steps=[('null_imputation',
#                                                                    SimpleImputer(fill_value='UNKNOWN',
#                                                                                  strategy='constant')),
#                                                                   ('ordinal_encoder',
#                                                                    OrdinalEncoder(han...
#                                eval_metric=['logloss'], gamma=0, gpu_id=-1,
#                                grow_policy='depthwise', importance_type=None,
#                                interaction_constraints='', learning_rate=0.1,
#                                max_bin=256, max_cat_to_onehot=4,
#                                max_delta_step=0, max_depth=6, max_leaves=0,
#                                min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=0, num_parallel_tree=1, predictor='auto',
#                                random_state=0, reg_alpha=0, reg_lambda=1, ...))])

# %%
eval_results = model.named_steps['model'].evals_result()

# %% [markdown]
# # Create and Save The Learning Curve

# %%
plt.plot(eval_results['validation_0']['logloss'], label='logloss')
plt.xlabel('Estimators')
plt.ylabel('Error')
plt.title('Learning Curve of the XGBoost Model')
plt.legend(['Logloss'])


# save the figure
plt.savefig('./artifact/learning_curve.png', dpi=300, bbox_inches='tight')


plt.show()

# %% [markdown]
# # Serialization

# %%
# Serialize and save the trained model
joblib.dump(model, "./deploy/model.pkl")
# Out:
# ['./deploy/model.pkl']

# %% [markdown]
# # Test & Validate Locally

# %%
# !drum score -cd ./deploy --input ./dataset/e2e_lending_club_scoring_2k.csv \
--target-type binary --positive-class-label 1 --negative-class-label 0 \
--verbose
# Out:
# Detected score mode
#
#
# ============================================================
# Component: Generic Predictor
# Output:
# ------------------------------------------------------------
# 2024-03-28 21:14:08,694 ERROR drum.PythonModelAdapter:  Failure when making predictions. Exception: ValueError("could not convert string to float: '7.29%'")
# Traceback (most recent call last):
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/adapters/model_adapters/python_model_adapter.py", line 571, in _predict_legacy_drum
#     predictions, model_labels = self._predictor_to_use.predict(data, model, **kwargs)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/artifact_predictors/xgboost_predictor.py", line 86, in predict
#     predictions = model.predict_proba(data)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/sklearn/pipeline.py", line 524, in predict_proba
#     return self.steps[-1][1].predict_proba(Xt, **predict_proba_params)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/xgboost/sklearn.py", line 1512, in predict_proba
#     class_probs = super().predict(
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/xgboost/sklearn.py", line 1049, in predict
#     predts = self.get_booster().inplace_predict(
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/xgboost/core.py", line 2146, in inplace_predict
#     data, _ = _ensure_np_dtype(data, data.dtype)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/xgboost/data.py", line 143, in _ensure_np_dtype
#     data = data.astype(np.float32, copy=False)
# ValueError: could not convert string to float: '7.29%'
# 2024-03-28 21:14:08,696 WARNING drum:  Looks like there is a problem.
# 2024-03-28 21:14:08,696 ERROR drum:  Failure when making predictions. Exception: ValueError("could not convert string to float: '7.29%'")
# Traceback (most recent call last):
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/adapters/model_adapters/python_model_adapter.py", line 571, in _predict_legacy_drum
#     predictions, model_labels = self._predictor_to_use.predict(data, model, **kwargs)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/artifact_predictors/xgboost_predictor.py", line 86, in predict
#     predictions = model.predict_proba(data)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/sklearn/pipeline.py", line 524, in predict_proba
#     return self.steps[-1][1].predict_proba(Xt, **predict_proba_params)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/xgboost/sklearn.py", line 1512, in predict_proba
#     class_probs = super().predict(
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/xgboost/sklearn.py", line 1049, in predict
#     predts = self.get_booster().inplace_predict(
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/xgboost/core.py", line 2146, in inplace_predict
#     data, _ = _ensure_np_dtype(data, data.dtype)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/xgboost/data.py", line 143, in _ensure_np_dtype
#     data = data.astype(np.float32, copy=False)
# ValueError: could not convert string to float: '7.29%'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/etc/system/kernel/.venv/bin/drum", line 8, in <module>
#     main()
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/main.py", line 113, in main
#     runtime.cm_runner.run()
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/drum.py", line 479, in run
#     self._run_predictions_pipelines_in_mlpiper()
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/drum.py", line 847, in _run_predictions_pipelines_in_mlpiper
#     self._pipeline_executor.run_pipeline(cleanup=False)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/mlpiper/pipeline/executor.py", line 280, in run_pipeline
#     self._run_pipeline()
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/mlpiper/pipeline/executor.py", line 251, in _run_pipeline
#     self._dag.run_connected_pipeline(self._ml_engine)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/mlpiper/pipeline/dag.py", line 137, in run_connected_pipeline
#     data_objs = dag_node.component_runner.run(parent_data_objs)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/mlpiper/pipeline/component_runner/python_connected_component_runner.py", line 14, in run
#     data_objs = self._dag_node.main_cls().materialize(parent_data_objs)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/mlpiper/components/connectable_component.py", line 11, in materialize
#     return self._materialize(parent_data_objs, self._ml_engine.user_data)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/resource/components/Python/generic_predictor/generic_predictor.py", line 134, in _materialize
#     predict_response = self._predictor.predict(
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/language_predictors/base_language_predictor.py", line 152, in predict
#     raw_predict_response = self._predict(**kwargs)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/language_predictors/python_predictor/python_predictor.py", line 118, in _predict
#     return self._model_adapter.predict(model=self._model, **kwargs)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/adapters/model_adapters/python_model_adapter.py", line 643, in predict
#     return self._predict_legacy_drum(data, model, **kwargs)
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/adapters/model_adapters/python_model_adapter.py", line 573, in _predict_legacy_drum
#     self._log_and_raise_final_error(exc, "Failure when making predictions.")
#   File "/etc/system/kernel/.venv/lib64/python3.9/site-packages/datarobot_drum/drum/adapters/model_adapters/python_model_adapter.py", line 109, in _log_and_raise_final_error
#     raise DrumPythonModelAdapterError(f"{message} Exception: {exc!r}")
# datarobot_drum.drum.adapters.model_adapters.python_model_adapter.DrumPythonModelAdapterError: Failure when making predictions. Exception: ValueError("could not convert string to float: '7.29%'")

# %%
# !drum validation  --code-dir ./deploy --input ./dataset/e2e_lending_club_scoring_2k.csv \
--target-type binary --positive-class-label 1 --negative-class-label 0
# Out:
# Validation checks results
#       Test case          Status   Details
# =========================================
# Basic batch prediction   PASSED
# Null value imputation    PASSED

# %%
# !drum --help
# Out:
# usage: drum [-h] [--version]
#             {score,fit,perf-test,validation,server,new,push} ...
#
# Run user model
#
# positional arguments:
#   {score,fit,perf-test,validation,server,new,push}
#                         Commands
#     score               Run predictions in batch mode
#     fit                 Fit your model to your data
#     perf-test           Run performance tests
#     validation          Run validation checks against the model
#     server              serve the model via REST APIs
#     new                 Create new model/env template
#     push                Add your modeling code into DataRobot
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --version             show program's version number and exit
