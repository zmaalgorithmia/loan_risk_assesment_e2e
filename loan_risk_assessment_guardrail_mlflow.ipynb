# %%
from datetime import datetime
import joblib
import pandas as pd
from matplotlib import pyplot as plt
import os
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_selector, ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from xgboost import XGBClassifier

# %% [markdown]
# # Exploratory Data Analysis

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("./dataset/DR_Demo_LendingClub_Guardrails_Partitioned.csv")

# %%
df.loc[df['is_bad'] == "Yes", 'is_bad'] = 1
df.loc[df['is_bad'] == "No", 'is_bad'] = 0
df['is_bad'] = df['is_bad'].astype('category')

# %%
df.head()
# Out:
#   is_bad member_id  loan_status                      emp_title emp_length  \
# 0      1  M1236516  Charged Off  Aqua Sun Lawn and Landscaping    5 years
# 1      0  M0978861   Fully Paid                      USDA/FMMA    9 years
# 2      0  M0767668   Fully Paid                 Doublepark LLC    3 years
# 3      0  M0879043   Fully Paid              City of Rochester    3 years
# 4      0  M0661671   Fully Paid           Roger George Rentals    9 years
#
#   home_ownership  annual_inc pymnt_plan desc zip_code addr_state    dti  \
# 0           RENT     50000.0          n  NaN    282xx         NC   7.99
# 1           RENT     34200.0          n  NaN    605xx         IL  22.74
# 2           RENT     30000.0          n  NaN    331xx         FL   2.36
# 3       MORTGAGE     51000.0          n  NaN    146xx         NY  11.20
# 4           RENT     44004.0          n  NaN    916xx         CA  22.47
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0          1.0          12/1/98             1.0                    19.0
# 1          2.0          11/1/71             2.0                    14.0
# 2          0.0           7/1/00             0.0                    72.0
# 3          0.0           5/1/98             1.0                     NaN
# 4          0.0           5/1/02             1.0                     NaN
#
#    mths_since_last_record  open_acc  pub_rec  revol_util  total_acc  \
# 0                     NaN       3.0      0.0        13.9        9.0
# 1                    45.0      10.0      1.0        80.6       31.0
# 2                     NaN       5.0      0.0        11.6        8.0
# 3                     NaN      13.0      0.0         0.0       23.0
# 4                     NaN      16.0      0.0        94.5       32.0
#
#    initial_list_status  collections_12_mths_ex_med  \
# 0                False                         0.0
# 1                False                         0.0
# 2                False                         0.0
# 3                False                         0.0
# 4                False                         0.0
#
#    mths_since_last_major_derog revol_util_percent  policy_code Partition
# 0                          NaN                14%            1         T
# 1                          NaN                81%            1         T
# 2                          NaN                12%            1         T
# 3                          NaN                 0%            1         T
# 4                          NaN                94%            1         T

# %% [markdown]
# # Feature Transformation

# %%
numeric_transform = SimpleImputer(strategy='constant', fill_value=0)
categoric_tranform = Pipeline(
    steps=[
        ('null_imputation', SimpleImputer(strategy='constant', fill_value='UNKNOWN')),
        ('ordinal_encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
    ]
)

# %%
# Col transfomer automatically handles right cols via datatypes
col_transformer = ColumnTransformer(
    transformers=[
        ('numeric', numeric_transform, make_column_selector(dtype_include=[float,int])),
        ('categoric', categoric_tranform, make_column_selector(dtype_include=object))
    ]
)

# %% [markdown]
# # Partitioning

# %%
training_data = df[df['Partition'] == "T"].drop(labels=['Partition'], axis=1)

# %%
training_data.shape
# Out:
# (6999, 26)

# %%
validation_data = df[df['Partition'] == "V"].drop(labels=['Partition'], axis=1)

# %%
validation_data.shape
# Out:
# (2000, 26)

# %%
X_train = training_data.drop(labels='is_bad', axis=1)
y_train = training_data['is_bad']
X_val = validation_data.drop(labels='is_bad', axis=1)
y_val = validation_data['is_bad']

# %% [markdown]
# # Set up MLflow for Experiment Tracking

# %%
import mlflow

# %%
mlflow.set_tracking_uri('https://9161-137-83-250-36.ngrok-free.app')
mlflow.set_experiment(experiment_name="kaggle_lending_club_xgboost")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/565145443302988224', creation_time=1684275426402, experiment_id='565145443302988224', last_update_time=1684275426402, lifecycle_stage='active', name='kaggle_lending_club_xgboost', tags={}>

# %%
mlflow.xgboost.autolog(log_models=True)

# %%
my_run_id = datetime.today().strftime('%Y-%m-%d_%H:%M:%S')
my_run_name="demo" + " " + my_run_id
run = mlflow.start_run(run_name=my_run_name)

# %%
mlflow.set_tag("Use Case Owner", "John Doe")
mlflow.set_tag("Data Scientist", "Zhilei Ma")

# %% [markdown]
# # Model Training & Evalution

# %%
xgb_model = XGBClassifier(
    learning_rate=.1,
    n_estimators=100,
    objective="binary:logistic",
    eval_metric=["logloss"],
    early_stopping_rounds=10,
    verbose=True
)

# %%
# Creates the model pipeline object:
model = Pipeline(
    steps=[
        ('col_transformer', col_transformer),
        ('model', xgb_model)
    ]
)

# %%
model[:-1].fit(X_train)
# Out:
# Pipeline(steps=[('col_transformer',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f67a49374f0>),
#                                                  ('categoric',
#                                                   Pipeline(steps=[('null_imputation',
#                                                                    SimpleImputer(fill_value='UNKNOWN',
#                                                                                  strategy='constant')),
#                                                                   ('ordinal_encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f675cf127f0>)]))])

# %%
X_val = model[:-1].transform(X_val)

# %%
model.fit(
    X_train, 
    y_train, 
    model__eval_set=[(X_val, y_val)]
)
# Out:
# 2024/04/16 18:53:21 WARNING mlflow.xgboost: Unable to log dataset information to MLflow Tracking.XGBoost version must be >= 1.7.0
# 2024/04/16 18:53:21 WARNING mlflow.xgboost: Unable to log dataset information to MLflow Tracking.XGBoost version must be >= 1.7.0
# [18:53:21] WARNING: ../src/learner.cc:627:
# Parameters: { "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-logloss:0.59850
# [1]	validation_0-logloss:0.52096
# [2]	validation_0-logloss:0.45629
# [3]	validation_0-logloss:0.40162
# [4]	validation_0-logloss:0.35492
# [5]	validation_0-logloss:0.31468
# [6]	validation_0-logloss:0.27978
# [7]	validation_0-logloss:0.24933
# [8]	validation_0-logloss:0.22265
# [9]	validation_0-logloss:0.19918
# [10]	validation_0-logloss:0.17846
# [11]	validation_0-logloss:0.16011
# [12]	validation_0-logloss:0.14382
# [13]	validation_0-logloss:0.12934
# [14]	validation_0-logloss:0.11643
# [15]	validation_0-logloss:0.10491
# [16]	validation_0-logloss:0.09461
# [17]	validation_0-logloss:0.08539
# [18]	validation_0-logloss:0.07712
# [19]	validation_0-logloss:0.06971
# [20]	validation_0-logloss:0.06306
# [21]	validation_0-logloss:0.05708
# [22]	validation_0-logloss:0.05170
# [23]	validation_0-logloss:0.04686
# [24]	validation_0-logloss:0.04251
# [25]	validation_0-logloss:0.03859
# [26]	validation_0-logloss:0.03508
# [27]	validation_0-logloss:0.03192
# [28]	validation_0-logloss:0.02907
# [29]	validation_0-logloss:0.02650
# [30]	validation_0-logloss:0.02418
# [31]	validation_0-logloss:0.02208
# [32]	validation_0-logloss:0.02017
# [33]	validation_0-logloss:0.01845
# [34]	validation_0-logloss:0.01689
# [35]	validation_0-logloss:0.01549
# [36]	validation_0-logloss:0.01421
# [37]	validation_0-logloss:0.01306
# [38]	validation_0-logloss:0.01203
# [39]	validation_0-logloss:0.01108
# [40]	validation_0-logloss:0.01023
# [41]	validation_0-logloss:0.00946
# [42]	validation_0-logloss:0.00876
# [43]	validation_0-logloss:0.00814
# [44]	validation_0-logloss:0.00757
# [45]	validation_0-logloss:0.00706
# [46]	validation_0-logloss:0.00659
# [47]	validation_0-logloss:0.00616
# [48]	validation_0-logloss:0.00577
# [49]	validation_0-logloss:0.00542
# [50]	validation_0-logloss:0.00511
# [51]	validation_0-logloss:0.00482
# [52]	validation_0-logloss:0.00456
# [53]	validation_0-logloss:0.00433
# [54]	validation_0-logloss:0.00412
# [55]	validation_0-logloss:0.00394
# [56]	validation_0-logloss:0.00376
# [57]	validation_0-logloss:0.00362
# [58]	validation_0-logloss:0.00349
# [59]	validation_0-logloss:0.00336
# [60]	validation_0-logloss:0.00324
# [61]	validation_0-logloss:0.00315
# [62]	validation_0-logloss:0.00304
# [63]	validation_0-logloss:0.00297
# [64]	validation_0-logloss:0.00293
# [65]	validation_0-logloss:0.00285
# [66]	validation_0-logloss:0.00283
# [67]	validation_0-logloss:0.00276
# [68]	validation_0-logloss:0.00277
# [69]	validation_0-logloss:0.00275
# [70]	validation_0-logloss:0.00271
# [71]	validation_0-logloss:0.00272
# [72]	validation_0-logloss:0.00272
# [73]	validation_0-logloss:0.00269
# [74]	validation_0-logloss:0.00271
# [75]	validation_0-logloss:0.00272
# [76]	validation_0-logloss:0.00269
# [77]	validation_0-logloss:0.00268
# [78]	validation_0-logloss:0.00271
# [79]	validation_0-logloss:0.00269
# [80]	validation_0-logloss:0.00267
# [81]	validation_0-logloss:0.00267
# [82]	validation_0-logloss:0.00270
# [83]	validation_0-logloss:0.00274
# [84]	validation_0-logloss:0.00277
# [85]	validation_0-logloss:0.00276
# [86]	validation_0-logloss:0.00274
# [87]	validation_0-logloss:0.00276
# [88]	validation_0-logloss:0.00276
# [89]	validation_0-logloss:0.00280
# [90]	validation_0-logloss:0.00279
# 2024/04/16 18:53:27 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during xgboost autologging: '__file__'
# Pipeline(steps=[('col_transformer',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f67a49374f0>),
#                                                  ('categoric',
#                                                   Pipeline(steps=[('null_imputation',
#                                                                    SimpleImputer(fill_value='UNKNOWN',
#                                                                                  strategy='constant')),
#                                                                   ('ordinal_encoder',
#                                                                    OrdinalEncoder(han...
#                                eval_metric=['logloss'], gamma=0, gpu_id=-1,
#                                grow_policy='depthwise', importance_type=None,
#                                interaction_constraints='', learning_rate=0.1,
#                                max_bin=256, max_cat_to_onehot=4,
#                                max_delta_step=0, max_depth=6, max_leaves=0,
#                                min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=0, num_parallel_tree=1, predictor='auto',
#                                random_state=0, reg_alpha=0, reg_lambda=1, ...))])

# %%
eval_results = model.named_steps['model'].evals_result()

# %% [markdown]
# # Create and Save The Learning Curve

# %%
plt.plot(eval_results['validation_0']['logloss'], label='logloss')
plt.xlabel('Estimators')
plt.ylabel('Error')
plt.title('Learning Curve of the XGBoost Model')
plt.legend(['Logloss'])


# save the figure
plt.savefig('./artifact/learning_curve.png', dpi=300, bbox_inches='tight')


plt.show()

# %%
# Log the plotted learning curve in MLflow 
mlflow.log_artifact("./artifact/learning_curve.png")

# %% [markdown]
# # Serialization

# %%
# Serialize and save the trained model
joblib.dump(model, "./deploy/model.pkl")
# Out:
# ['./deploy/model.pkl']

# %% [markdown]
# # Test & Validate Locally

# %%
# !drum score -cd ./deploy --input ./dataset/DR_Demo_LendingClub_Guardrails_SCORING.csv \
--target-type binary --positive-class-label 1 --negative-class-label 0 \
--verbose
# Out:
# Detected score mode
#
#
# ============================================================
# Component: Generic Predictor
# Output:
# ------------------------------------------------------------
# ------------------------------------------------------------
# Runtime:    0.1 sec
# NR outputs: 0
# ============================================================
#
#             0         1
# 0    0.999423  0.000577
# 1    0.999321  0.000679
# 2    0.999763  0.000237
# 3    0.999733  0.000267
# 4    0.999608  0.000392
# ..        ...       ...
# 495  0.999559  0.000441
# 496  0.000657  0.999343
# 497  0.998968  0.001032
# 498  0.999559  0.000441
# 499  0.996289  0.003711
#
# [500 rows x 2 columns]

# %%
# !drum validation  --code-dir ./deploy --input ./dataset/DR_Demo_LendingClub_Guardrails_SCORING.csv \
--target-type binary --positive-class-label 1 --negative-class-label 0
# Out:
# Validation checks results
#       Test case          Status   Details
# =========================================
# Basic batch prediction   PASSED
# Null value imputation    PASSED

# %%
# !drum --help
# Out:
# usage: drum [-h] [--version]
#             {score,fit,perf-test,validation,server,new,push} ...
#
# Run user model
#
# positional arguments:
#   {score,fit,perf-test,validation,server,new,push}
#                         Commands
#     score               Run predictions in batch mode
#     fit                 Fit your model to your data
#     perf-test           Run performance tests
#     validation          Run validation checks against the model
#     server              serve the model via REST APIs
#     new                 Create new model/env template
#     push                Add your modeling code into DataRobot
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --version             show program's version number and exit
